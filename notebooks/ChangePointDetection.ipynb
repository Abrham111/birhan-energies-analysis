# %%
import pandas as pd
import sys
sys.path.append("../scripts")

# %%
df = pd.read_csv("../data/BrentOilPrices.csv")

# %% [markdown]
# # Change point analysis

# %%
# Change point analysis
from change_point_detection import detect_change_points

change_points = detect_change_points(df)
print("Detected Change Points:", change_points)
# Out:
# Detected Change Points: [820, 935, 2695, 3100, 4220, 4370, 4600, 5090, 5200, 5315, 5415, 5445, 5595, 5695, 5980, 6035, 6340, 6925, 6985, 7155, 7350, 7700, 7840, 7990, 8330, 8380, 8540, 8640, 8815, 8940, 9011]
